# %% [markdown]
# # Minimierung der Lateness jedes Produktionsauftrags

# %% [markdown]
# $$
# L_j = C_j - d_j
# $$
#
#
# - $L_j$: Lateness (Verspätung oder Frühfertigung) des Jobs $j$
# - $C_j$: tatsächliche Fertigstellungszeit (Completion Time) von Job $j$
# - $d_j$: Deadline bzw. geplanter Fertigstellungstermin von Job $j$
#
# **Interpretation:**
#
# - $L_j > 0$: Job ist **verspätet**
# - $L_j = 0$: Job ist **pünktlich**
# - $L_j < 0$: Job ist **zu früh** fertig

# %%
import pandas as pd

# Utils
import src.utils.visualization.gantt_diagram as gantt
from src.utils.analysis_basics import check_constraints as check
from src.utils.rolling_process.rolling_filter import *

from src.utils.editor import enrich_schedule_dframe

# Solver
from src.solvers.converter import get_job_ops_dict, get_times_dict, get_schedule_dframe, get_active_ops
from src.solvers.cp.lateness import solve_jssp_lateness_with_start_deviation

# Simulation
from src.simulation.ProductionRollingSimulation import ProductionSimulation

# Data access
from configs.path_manager import get_path

pd.set_option('display.min_rows', 12)
pd.set_option('display.max_rows', 16)

# %%
# Harte Abbruchbedingung für die Scheduler
max_time = 60*3     # 3 min

# Simulation
simulation = ProductionSimulation(sigma = 0.2)

# %%
basic_data_path = get_path("data", "basic")
df_jssp = pd.read_csv(basic_data_path / "jssp_final.csv")
df_jssp
# Out:
#             Job  Routing_ID  Operation Machine  Processing Time
# 0      J25-0000           8          0     M00               76
# 1      J25-0000           8          1     M01               69
# 2      J25-0000           8          2     M03               76
# 3      J25-0000           8          3     M05               51
# 4      J25-0000           8          4     M02               85
# 5      J25-0000           8          5     M09               11
# ...         ...         ...        ...     ...              ...
# 72494  J25-7249           4          4     M03               26
# 72495  J25-7249           4          5     M04               69
# 72496  J25-7249           4          6     M08               21
# 72497  J25-7249           4          7     M07               49
# 72498  J25-7249           4          8     M09               72
# 72499  J25-7249           4          9     M06               53
#
# [72500 rows x 5 columns]

# %%
df_jobs_times = pd.read_csv(basic_data_path / "jobs_times_final.csv")
df_jobs_times
# Out:
#            Job  Routing_ID  Arrival  Ready Time  Job Processing Time  Deadline
# 0     J25-0000           8       79        1440                  597      3660
# 1     J25-0001           6      129        1440                  416      2338
# 2     J25-0002           0      198        1440                  395      3744
# 3     J25-0003           2      243        1440                  568      3379
# 4     J25-0004           3      287        1440                  655      4856
# 5     J25-0005           1      498        1440                  510      3106
# ...        ...         ...      ...         ...                  ...       ...
# 7244  J25-7244           3   518085      518400                  655    520389
# 7245  J25-7245           9   518089      518400                  540    519640
# 7246  J25-7246           6   518116      518400                  416    520157
# 7247  J25-7247           1   518184      518400                  510    520172
# 7248  J25-7248           0   518188      518400                  395    520490
# 7249  J25-7249           4   518302      518400                  393    522163
#
# [7250 rows x 6 columns]

# %% [markdown]
# ## Day 1
# - On day 0, the first jobs (production orders) arrive, so nothing can be planned yet
# - On day 1, the initial planning takes place

# %%
day_length = 1440

day_numb = 1
day_start = day_length*day_numb
day_end = day_start + day_length
print(f"Tag {day_numb:02d}: [{day_start}, {day_end})")
# Out:
# Tag 01: [1440, 2880)

# %%
# New and unfinished jobs
df_jobs_times_current = get_current_jobs(
    df_jobs_times, df_previous_not_started = None, ready_time=day_start
)
df_jobs_times_current
# Out:
#          Job  Routing_ID  Arrival  Ready Time  Job Processing Time  Deadline
# 0   J25-0000           8       79        1440                  597      3660
# 1   J25-0001           6      129        1440                  416      2338
# 2   J25-0002           0      198        1440                  395      3744
# 3   J25-0003           2      243        1440                  568      3379
# 4   J25-0004           3      287        1440                  655      4856
# 5   J25-0005           1      498        1440                  510      3106
# 6   J25-0006           9      790        1440                  540      3539
# 7   J25-0007           5      925        1440                  496      2929
# 8   J25-0008           4      988        1440                  393      3541
# 9   J25-0009           7     1004        1440                  539      3578
# 10  J25-0010           0     1025        1440                  395      3345
# 11  J25-0011           1     1030        1440                  510      3210
# 12  J25-0012           2     1103        1440                  568      4385
# 13  J25-0013           3     1192        1440                  655      2567
# 14  J25-0014           4     1222        1440                  393      3315
# 15  J25-0015           5     1436        1440                  496      2981

# %%
# current JSSP (Job Shop Scheduling Problem) basic data
df_jssp_current = filter_current_jssp(df_jssp, df_jobs_times_current, exclusion_dataframes_list = None)
df_jssp_current
# Out:
#           Job  Routing_ID  Operation Machine  Processing Time
# 0    J25-0000           8          0     M00               76
# 1    J25-0000           8          1     M01               69
# 2    J25-0000           8          2     M03               76
# 3    J25-0000           8          3     M05               51
# 4    J25-0000           8          4     M02               85
# 5    J25-0000           8          5     M09               11
# ..        ...         ...        ...     ...              ...
# 154  J25-0015           5          4     M08               48
# 155  J25-0015           5          5     M09               72
# 156  J25-0015           5          6     M00               47
# 157  J25-0015           5          7     M06               65
# 158  J25-0015           5          8     M04                6
# 159  J25-0015           5          9     M07               25
#
# [160 rows x 5 columns]

# %% [markdown]
# ### Scheduling Preperation

# %%
job_ops_dict = get_job_ops_dict(df_jssp_current)
job_ops_dict
# Out:
# {'J25-0000': [(0, 'M00', 76),
#   (1, 'M01', 69),
#   (2, 'M03', 76),
#   (3, 'M05', 51),
#   (4, 'M02', 85),
#   (5, 'M09', 11),
#   (6, 'M06', 40),
#   (7, 'M07', 89),
#   (8, 'M04', 26),
#   (9, 'M08', 74)],
#  'J25-0001': [(0, 'M01', 46),
#   (1, 'M00', 37),
#   (2, 'M03', 61),
#   (3, 'M02', 13),
#   (4, 'M06', 32),
#   (5, 'M05', 21),
#   (6, 'M09', 32),
#   (7, 'M08', 89),
#   (8, 'M07', 30),
#   (9, 'M04', 55)],
#  'J25-0002': [(0, 'M00', 29),
#   (1, 'M01', 78),
#   (2, 'M02', 9),
#   (3, 'M03', 36),
#   (4, 'M04', 49),
#   (5, 'M05', 11),
#   (6, 'M06', 62),
#   (7, 'M07', 56),
#   (8, 'M08', 44),
#   (9, 'M09', 21)],
#  'J25-0003': [(0, 'M01', 91),
#   (1, 'M00', 85),
#   (2, 'M03', 39),
#   (3, 'M02', 74),
#   (4, 'M08', 90),
#   (5, 'M05', 10),
#   (6, 'M07', 12),
#   (7, 'M06', 89),
#   (8, 'M09', 45),
#   (9, 'M04', 33)],
#  'J25-0004': [(0, 'M01', 81),
#   (1, 'M02', 95),
#   (2, 'M00', 71),
#   (3, 'M04', 99),
#   (4, 'M06', 9),
#   (5, 'M08', 52),
#   (6, 'M07', 85),
#   (7, 'M03', 98),
#   (8, 'M09', 22),
#   (9, 'M05', 43)],
#  'J25-0005': [(0, 'M00', 43),
#   (1, 'M02', 90),
#   (2, 'M04', 75),
#   (3, 'M09', 11),
#   (4, 'M03', 69),
#   (5, 'M01', 28),
#   (6, 'M06', 46),
#   (7, 'M05', 46),
#   (8, 'M07', 72),
#   (9, 'M08', 30)],
#  'J25-0006': [(0, 'M01', 85),
#   (1, 'M00', 13),
#   (2, 'M02', 61),
#   (3, 'M06', 7),
#   (4, 'M08', 64),
#   (5, 'M09', 76),
#   (6, 'M05', 47),
#   (7, 'M03', 52),
#   (8, 'M04', 90),
#   (9, 'M07', 45)],
#  'J25-0007': [(0, 'M02', 84),
#   (1, 'M01', 2),
#   (2, 'M05', 52),
#   (3, 'M03', 95),
#   (4, 'M08', 48),
#   (5, 'M09', 72),
#   (6, 'M00', 47),
#   (7, 'M06', 65),
#   (8, 'M04', 6),
#   (9, 'M07', 25)],
#  'J25-0008': [(0, 'M02', 14),
#   (1, 'M00', 6),
#   (2, 'M01', 22),
#   (3, 'M05', 61),
#   (4, 'M03', 26),
#   (5, 'M04', 69),
#   (6, 'M08', 21),
#   (7, 'M07', 49),
#   (8, 'M09', 72),
#   (9, 'M06', 53)],
#  'J25-0009': [(0, 'M02', 31),
#   (1, 'M00', 86),
#   (2, 'M01', 46),
#   (3, 'M05', 74),
#   (4, 'M04', 32),
#   (5, 'M06', 88),
#   (6, 'M08', 19),
#   (7, 'M09', 48),
#   (8, 'M07', 36),
#   (9, 'M03', 79)],
#  'J25-0010': [(0, 'M00', 29),
#   (1, 'M01', 78),
#   (2, 'M02', 9),
#   (3, 'M03', 36),
#   (4, 'M04', 49),
#   (5, 'M05', 11),
#   (6, 'M06', 62),
#   (7, 'M07', 56),
#   (8, 'M08', 44),
#   (9, 'M09', 21)],
#  'J25-0011': [(0, 'M00', 43),
#   (1, 'M02', 90),
#   (2, 'M04', 75),
#   (3, 'M09', 11),
#   (4, 'M03', 69),
#   (5, 'M01', 28),
#   (6, 'M06', 46),
#   (7, 'M05', 46),
#   (8, 'M07', 72),
#   (9, 'M08', 30)],
#  'J25-0012': [(0, 'M01', 91),
#   (1, 'M00', 85),
#   (2, 'M03', 39),
#   (3, 'M02', 74),
#   (4, 'M08', 90),
#   (5, 'M05', 10),
#   (6, 'M07', 12),
#   (7, 'M06', 89),
#   (8, 'M09', 45),
#   (9, 'M04', 33)],
#  'J25-0013': [(0, 'M01', 81),
#   (1, 'M02', 95),
#   (2, 'M00', 71),
#   (3, 'M04', 99),
#   (4, 'M06', 9),
#   (5, 'M08', 52),
#   (6, 'M07', 85),
#   (7, 'M03', 98),
#   (8, 'M09', 22),
#   (9, 'M05', 43)],
#  'J25-0014': [(0, 'M02', 14),
#   (1, 'M00', 6),
#   (2, 'M01', 22),
#   (3, 'M05', 61),
#   (4, 'M03', 26),
#   (5, 'M04', 69),
#   (6, 'M08', 21),
#   (7, 'M07', 49),
#   (8, 'M09', 72),
#   (9, 'M06', 53)],
#  'J25-0015': [(0, 'M02', 84),
#   (1, 'M01', 2),
#   (2, 'M05', 52),
#   (3, 'M03', 95),
#   (4, 'M08', 48),
#   (5, 'M09', 72),
#   (6, 'M00', 47),
#   (7, 'M06', 65),
#   (8, 'M04', 6),
#   (9, 'M07', 25)]}

# %%
times_dict = get_times_dict(df_jobs_times_current)
times_dict
# Out:
# {'J25-0000': (1440, 3660),
#  'J25-0001': (1440, 2338),
#  'J25-0002': (1440, 3744),
#  'J25-0003': (1440, 3379),
#  'J25-0004': (1440, 4856),
#  'J25-0005': (1440, 3106),
#  'J25-0006': (1440, 3539),
#  'J25-0007': (1440, 2929),
#  'J25-0008': (1440, 3541),
#  'J25-0009': (1440, 3578),
#  'J25-0010': (1440, 3345),
#  'J25-0011': (1440, 3210),
#  'J25-0012': (1440, 4385),
#  'J25-0013': (1440, 2567),
#  'J25-0014': (1440, 3315),
#  'J25-0015': (1440, 2981)}

# %% [markdown]
# ### Schedule

# %%
schedule = solve_jssp_lateness_with_start_deviation(
        job_ops=job_ops_dict,
        times_dict=times_dict,
        previous_schedule=None,
        active_ops=None,
        w_t= 10, w_e=2, w_first=1,
        main_pct=1, duration_buffer_factor = 2,
        schedule_start=day_start, msg=False,
        solver_time_limit=max_time, solver_relative_gap_limit=0.05
    )
# Out:
# Model Information
#   Number of variables       : 421
#   Number of constraints     : 575
#   Deviation terms (IntVars) : 0
#
# Solver Information
#   Solver status             : OPTIMAL
#   Objective value           : 0.0
#   Best objective bound      : 0.0
#   Number of branches        : 73
#   Wall time                 : 0.09 seconds

# %%
df_schedule = get_schedule_dframe(schedule)
df_schedule
# Out:
#           Job  Operation Machine  Start  Processing Time   End
# 0    J25-0000          0     M00   2481               76  2557
# 1    J25-0000          1     M01   2594               69  2663
# 2    J25-0000          2     M03   2681               76  2757
# 3    J25-0000          3     M05   2783               51  2834
# 4    J25-0000          4     M02   2834               85  2919
# 5    J25-0000          5     M09   2970               11  2981
# ..        ...        ...     ...    ...              ...   ...
# 154  J25-0015          4     M08   2277               48  2325
# 155  J25-0015          5     M09   2325               72  2397
# 156  J25-0015          6     M00   2434               47  2481
# 157  J25-0015          7     M06   2481               65  2546
# 158  J25-0015          8     M04   2546                6  2552
# 159  J25-0015          9     M07   2956               25  2981
#
# [160 rows x 6 columns]

# %%
gantt.get_plot(df_schedule, perspective="Machine")

df_schedule_with_info = enrich_schedule_dframe(df_schedule, df_jobs_times)
check.all_in_one(df_schedule_with_info)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
#
# +++ Alle Constraints wurden erfüllt.
# True

# %% [markdown]
# ### Simulation

# %%
simulation.run(dframe_schedule_plan = df_schedule, start_time = day_start, end_time=day_end)
# Out:
# [Day 1 00:00:00] Job J25-0013 started on M01
# [Day 1 01:35:00] Job J25-0013 finished on M01 (after 95 minutes)
# [Day 1 01:35:00] Job J25-0001 started on M01
# [Day 1 01:35:00] Job J25-0013 started on M02
# [Day 1 02:18:00] Job J25-0001 finished on M01 (after 43 minutes)
# [Day 1 02:18:00] Job J25-0001 started on M00
# [Day 1 02:56:00] Job J25-0001 finished on M00 (after 38 minutes)
# [Day 1 22:02:00] Job J25-0010 finished on M01 (after 68 minutes)
# [Day 1 22:02:00] Job J25-0005 finished on M07 (after 61 minutes)
# [Day 1 22:07:00] Job J25-0008 finished on M02 (after 12 minutes)
# [Day 1 22:09:00] Job J25-0009 started on M01
# [Day 1 22:09:00] Job J25-0010 started on M02
# [Day 1 22:09:00] Job J25-0008 started on M00
# [Day 1 22:11:00] Job J25-0006 started on M08
# [Day 1 22:15:00] Job J25-0008 finished on M00 (after 06 minutes)
# [Day 1 22:17:00] Job J25-0010 finished on M02 (after 08 minutes)
# [Day 1 22:18:00] Job J25-0010 started on M03
# [Day 1 22:25:00] Job J25-0014 finished on M04 (after 104 minutes)
# [Day 1 22:31:00] Job J25-0011 finished on M05 (after 44 minutes)
# [Day 1 22:31:00] Job J25-0000 started on M05
# [Day 1 22:47:00] Job J25-0010 finished on M03 (after 29 minutes)
# [Day 1 22:54:00] Job J25-0010 started on M04
# [Day 1 23:02:00] Job J25-0011 started on M07
# [Day 1 23:06:00] Job J25-0009 finished on M01 (after 57 minutes)
# [Day 1 23:06:00] Job J25-0008 started on M01
# [Day 1 23:20:00] Job J25-0006 finished on M08 (after 69 minutes)
# [Day 1 23:20:00] Job J25-0014 started on M08
# [Day 1 23:29:00] Job J25-0008 finished on M01 (after 23 minutes)
# [Day 1 23:32:00] Job J25-0000 finished on M05 (after 61 minutes)
# [Day 1 23:32:00] Job J25-0009 started on M05
# [Day 1 23:32:00] Job J25-0000 started on M02
# [Day 1 23:43:00] Job J25-0014 finished on M08 (after 23 minutes)
# [Day 1 23:44:00] Job J25-0010 finished on M04 (after 50 minutes)

# %%
df_execution = simulation.get_finished_operations_df()
df_execution
# Out:
#          Job  Operation Machine   Start  Processing Time     End
# 0   J25-0000          0     M00  2481.0             79.0  2560.0
# 1   J25-0000          1     M01  2601.0             43.0  2644.0
# 2   J25-0000          2     M03  2681.0             80.0  2761.0
# 3   J25-0000          3     M05  2791.0             61.0  2852.0
# 4   J25-0001          0     M01  1535.0             43.0  1578.0
# 5   J25-0001          1     M00  1578.0             38.0  1616.0
# ..       ...        ...     ...     ...              ...     ...
# 82  J25-0015          3     M03  2182.0            106.0  2288.0
# 83  J25-0015          4     M08  2288.0             63.0  2351.0
# 84  J25-0015          5     M09  2351.0             66.0  2417.0
# 85  J25-0015          6     M00  2434.0             39.0  2473.0
# 86  J25-0015          7     M06  2481.0             59.0  2540.0
# 87  J25-0015          8     M04  2546.0              6.0  2552.0
#
# [88 rows x 6 columns]

# %%
gantt.get_plot(df_execution, perspective="Machine")

# %%
df_active = simulation.get_active_operations_df()
df_active
# Out:
#         Job  Operation Machine   Start  Processing Time     End  Expected End
# 0  J25-0000          4     M02  2852.0             93.0  2945.0        2937.0
# 1  J25-0009          3     M05  2852.0             65.0  2917.0        2926.0
# 2  J25-0011          8     M07  2822.0             77.0  2899.0        2894.0

# %%
df_not_started = simulation.get_not_started_operations_df(df_schedule)
df_not_started
# Out:
#          Job  Operation Machine  Start  Processing Time   End
# 0   J25-0000          5     M09   2970               11  2981
# 1   J25-0000          6     M06   3158               40  3198
# 2   J25-0000          7     M07   3220               89  3309
# 3   J25-0000          8     M04   3309               26  3335
# 4   J25-0000          9     M08   3586               74  3660
# 5   J25-0002          0     M00   2954               29  2983
# ..       ...        ...     ...    ...              ...   ...
# 63  J25-0012          8     M09   3861               45  3906
# 64  J25-0012          9     M04   4352               33  4385
# 65  J25-0014          7     M07   2773               49  2822
# 66  J25-0014          8     M09   2822               72  2894
# 67  J25-0014          9     M06   3262               53  3315
# 68  J25-0015          9     M07   2956               25  2981
#
# [69 rows x 6 columns]

# %% [markdown]
# ## Day 2
# - This is where the new scheduling takes place, i.e., scheduling with specific consideration of the simulation.

# %%
day_numb = 2
day_start = day_length*day_numb
day_end = day_start + day_length
print(f"Tag {day_numb:02d}: [{day_start}, {day_end})")
# Out:
# Tag 02: [2880, 4320)

# %%
# New and unfinished jobs
df_jobs_times_current = get_current_jobs(df_jobs_times, df_not_started, ready_time=day_start)
df_jobs_times_current
# Out:
#          Job  Routing_ID  Arrival  Ready Time  Job Processing Time  Deadline
# 0   J25-0000           8       79        1440                  597      3660
# 2   J25-0002           0      198        1440                  395      3744
# 3   J25-0003           2      243        1440                  568      3379
# 4   J25-0004           3      287        1440                  655      4856
# 5   J25-0005           1      498        1440                  510      3106
# 6   J25-0006           9      790        1440                  540      3539
# ..       ...         ...      ...         ...                  ...       ...
# 32  J25-0032           6     2654        2880                  416      3881
# 33  J25-0033           2     2660        2880                  568      6738
# 34  J25-0034           8     2715        2880                  597      6387
# 35  J25-0035           5     2726        2880                  496      4126
# 36  J25-0036           4     2734        2880                  393      5231
# 37  J25-0037           7     2801        2880                  539      5173
#
# [36 rows x 6 columns]

# %%
df_jssp_current = filter_current_jssp(
    df_jssp = df_jssp,
    df_jobs_times_current = df_jobs_times_current,
    exclusion_dataframes_list = [df_active, df_execution]
)
df_jssp_current
# Out:
#           Job  Routing_ID  Operation Machine  Processing Time
# 5    J25-0000           8          5     M09               11
# 6    J25-0000           8          6     M06               40
# 7    J25-0000           8          7     M07               89
# 8    J25-0000           8          8     M04               26
# 9    J25-0000           8          9     M08               74
# 20   J25-0002           0          0     M00               29
# ..        ...         ...        ...     ...              ...
# 374  J25-0037           7          4     M04               32
# 375  J25-0037           7          5     M06               88
# 376  J25-0037           7          6     M08               19
# 377  J25-0037           7          7     M09               48
# 378  J25-0037           7          8     M07               36
# 379  J25-0037           7          9     M03               79
#
# [289 rows x 5 columns]

# %% [markdown]
# ### Scheduling Preparation

# %%
job_ops_dict = get_job_ops_dict(df_jssp_current)
job_ops_dict
# Out:
# {'J25-0000': [(5, 'M09', 11),
#   (6, 'M06', 40),
#   (7, 'M07', 89),
#   (8, 'M04', 26),
#   (9, 'M08', 74)],
#  'J25-0002': [(0, 'M00', 29),
#   (1, 'M01', 78),
#   (2, 'M02', 9),
#   (3, 'M03', 36),
#   (4, 'M04', 49),
#   (5, 'M05', 11),
#   (6, 'M06', 62),
#   (7, 'M07', 56),
#   (8, 'M08', 44),
#   (9, 'M09', 21)],
#  'J25-0003': [(6, 'M07', 12), (7, 'M06', 89), (8, 'M09', 45), (9, 'M04', 33)],
#  'J25-0004': [(0, 'M01', 81),
#   (1, 'M02', 95),
#   (2, 'M00', 71),
#   (3, 'M04', 99),
#   (4, 'M06', 9),
#   (5, 'M08', 52),
#   (6, 'M07', 85),
#   (7, 'M03', 98),
#   (8, 'M09', 22),
#   (9, 'M05', 43)],
#  'J25-0005': [(9, 'M08', 30)],
#  'J25-0006': [(5, 'M09', 76),
#   (6, 'M05', 47),
#   (7, 'M03', 52),
#   (8, 'M04', 90),
#   (9, 'M07', 45)],
#  'J25-0007': [(9, 'M07', 25)],
#  'J25-0008': [(3, 'M05', 61),
#   (4, 'M03', 26),
#   (5, 'M04', 69),
#   (6, 'M08', 21),
#   (7, 'M07', 49),
#   (8, 'M09', 72),
#   (9, 'M06', 53)],
#  'J25-0009': [(4, 'M04', 32),
#   (5, 'M06', 88),
#   (6, 'M08', 19),
#   (7, 'M09', 48),
#   (8, 'M07', 36),
#   (9, 'M03', 79)],
#  'J25-0010': [(5, 'M05', 11),
#   (6, 'M06', 62),
#   (7, 'M07', 56),
#   (8, 'M08', 44),
#   (9, 'M09', 21)],
#  'J25-0011': [(9, 'M08', 30)],
#  'J25-0012': [(0, 'M01', 91),
#   (1, 'M00', 85),
#   (2, 'M03', 39),
#   (3, 'M02', 74),
#   (4, 'M08', 90),
#   (5, 'M05', 10),
#   (6, 'M07', 12),
#   (7, 'M06', 89),
#   (8, 'M09', 45),
#   (9, 'M04', 33)],
#  'J25-0014': [(7, 'M07', 49), (8, 'M09', 72), (9, 'M06', 53)],
#  'J25-0015': [(9, 'M07', 25)],
#  'J25-0016': [(0, 'M01', 46),
#   (1, 'M00', 37),
#   (2, 'M03', 61),
#   (3, 'M02', 13),
#   (4, 'M06', 32),
#   (5, 'M05', 21),
#   (6, 'M09', 32),
#   (7, 'M08', 89),
#   (8, 'M07', 30),
#   (9, 'M04', 55)],
#  'J25-0017': [(0, 'M02', 31),
#   (1, 'M00', 86),
#   (2, 'M01', 46),
#   (3, 'M05', 74),
#   (4, 'M04', 32),
#   (5, 'M06', 88),
#   (6, 'M08', 19),
#   (7, 'M09', 48),
#   (8, 'M07', 36),
#   (9, 'M03', 79)],
#  'J25-0018': [(0, 'M00', 76),
#   (1, 'M01', 69),
#   (2, 'M03', 76),
#   (3, 'M05', 51),
#   (4, 'M02', 85),
#   (5, 'M09', 11),
#   (6, 'M06', 40),
#   (7, 'M07', 89),
#   (8, 'M04', 26),
#   (9, 'M08', 74)],
#  'J25-0019': [(0, 'M01', 85),
#   (1, 'M00', 13),
#   (2, 'M02', 61),
#   (3, 'M06', 7),
#   (4, 'M08', 64),
#   (5, 'M09', 76),
#   (6, 'M05', 47),
#   (7, 'M03', 52),
#   (8, 'M04', 90),
#   (9, 'M07', 45)],
#  'J25-0020': [(0, 'M00', 43),
#   (1, 'M02', 90),
#   (2, 'M04', 75),
#   (3, 'M09', 11),
#   (4, 'M03', 69),
#   (5, 'M01', 28),
#   (6, 'M06', 46),
#   (7, 'M05', 46),
#   (8, 'M07', 72),
#   (9, 'M08', 30)],
#  'J25-0021': [(0, 'M02', 84),
#   (1, 'M01', 2),
#   (2, 'M05', 52),
#   (3, 'M03', 95),
#   (4, 'M08', 48),
#   (5, 'M09', 72),
#   (6, 'M00', 47),
#   (7, 'M06', 65),
#   (8, 'M04', 6),
#   (9, 'M07', 25)],
#  'J25-0022': [(0, 'M01', 85),
#   (1, 'M00', 13),
#   (2, 'M02', 61),
#   (3, 'M06', 7),
#   (4, 'M08', 64),
#   (5, 'M09', 76),
#   (6, 'M05', 47),
#   (7, 'M03', 52),
#   (8, 'M04', 90),
#   (9, 'M07', 45)],
#  'J25-0023': [(0, 'M00', 76),
#   (1, 'M01', 69),
#   (2, 'M03', 76),
#   (3, 'M05', 51),
#   (4, 'M02', 85),
#   (5, 'M09', 11),
#   (6, 'M06', 40),
#   (7, 'M07', 89),
#   (8, 'M04', 26),
#   (9, 'M08', 74)],
#  'J25-0024': [(0, 'M01', 81),
#   (1, 'M02', 95),
#   (2, 'M00', 71),
#   (3, 'M04', 99),
#   (4, 'M06', 9),
#   (5, 'M08', 52),
#   (6, 'M07', 85),
#   (7, 'M03', 98),
#   (8, 'M09', 22),
#   (9, 'M05', 43)],
#  'J25-0025': [(0, 'M01', 91),
#   (1, 'M00', 85),
#   (2, 'M03', 39),
#   (3, 'M02', 74),
#   (4, 'M08', 90),
#   (5, 'M05', 10),
#   (6, 'M07', 12),
#   (7, 'M06', 89),
#   (8, 'M09', 45),
#   (9, 'M04', 33)],
#  'J25-0026': [(0, 'M01', 46),
#   (1, 'M00', 37),
#   (2, 'M03', 61),
#   (3, 'M02', 13),
#   (4, 'M06', 32),
#   (5, 'M05', 21),
#   (6, 'M09', 32),
#   (7, 'M08', 89),
#   (8, 'M07', 30),
#   (9, 'M04', 55)],
#  'J25-0027': [(0, 'M02', 31),
#   (1, 'M00', 86),
#   (2, 'M01', 46),
#   (3, 'M05', 74),
#   (4, 'M04', 32),
#   (5, 'M06', 88),
#   (6, 'M08', 19),
#   (7, 'M09', 48),
#   (8, 'M07', 36),
#   (9, 'M03', 79)],
#  'J25-0028': [(0, 'M00', 29),
#   (1, 'M01', 78),
#   (2, 'M02', 9),
#   (3, 'M03', 36),
#   (4, 'M04', 49),
#   (5, 'M05', 11),
#   (6, 'M06', 62),
#   (7, 'M07', 56),
#   (8, 'M08', 44),
#   (9, 'M09', 21)],
#  'J25-0029': [(0, 'M02', 14),
#   (1, 'M00', 6),
#   (2, 'M01', 22),
#   (3, 'M05', 61),
#   (4, 'M03', 26),
#   (5, 'M04', 69),
#   (6, 'M08', 21),
#   (7, 'M07', 49),
#   (8, 'M09', 72),
#   (9, 'M06', 53)],
#  'J25-0030': [(0, 'M00', 29),
#   (1, 'M01', 78),
#   (2, 'M02', 9),
#   (3, 'M03', 36),
#   (4, 'M04', 49),
#   (5, 'M05', 11),
#   (6, 'M06', 62),
#   (7, 'M07', 56),
#   (8, 'M08', 44),
#   (9, 'M09', 21)],
#  'J25-0031': [(0, 'M00', 43),
#   (1, 'M02', 90),
#   (2, 'M04', 75),
#   (3, 'M09', 11),
#   (4, 'M03', 69),
#   (5, 'M01', 28),
#   (6, 'M06', 46),
#   (7, 'M05', 46),
#   (8, 'M07', 72),
#   (9, 'M08', 30)],
#  'J25-0032': [(0, 'M01', 46),
#   (1, 'M00', 37),
#   (2, 'M03', 61),
#   (3, 'M02', 13),
#   (4, 'M06', 32),
#   (5, 'M05', 21),
#   (6, 'M09', 32),
#   (7, 'M08', 89),
#   (8, 'M07', 30),
#   (9, 'M04', 55)],
#  'J25-0033': [(0, 'M01', 91),
#   (1, 'M00', 85),
#   (2, 'M03', 39),
#   (3, 'M02', 74),
#   (4, 'M08', 90),
#   (5, 'M05', 10),
#   (6, 'M07', 12),
#   (7, 'M06', 89),
#   (8, 'M09', 45),
#   (9, 'M04', 33)],
#  'J25-0034': [(0, 'M00', 76),
#   (1, 'M01', 69),
#   (2, 'M03', 76),
#   (3, 'M05', 51),
#   (4, 'M02', 85),
#   (5, 'M09', 11),
#   (6, 'M06', 40),
#   (7, 'M07', 89),
#   (8, 'M04', 26),
#   (9, 'M08', 74)],
#  'J25-0035': [(0, 'M02', 84),
#   (1, 'M01', 2),
#   (2, 'M05', 52),
#   (3, 'M03', 95),
#   (4, 'M08', 48),
#   (5, 'M09', 72),
#   (6, 'M00', 47),
#   (7, 'M06', 65),
#   (8, 'M04', 6),
#   (9, 'M07', 25)],
#  'J25-0036': [(0, 'M02', 14),
#   (1, 'M00', 6),
#   (2, 'M01', 22),
#   (3, 'M05', 61),
#   (4, 'M03', 26),
#   (5, 'M04', 69),
#   (6, 'M08', 21),
#   (7, 'M07', 49),
#   (8, 'M09', 72),
#   (9, 'M06', 53)],
#  'J25-0037': [(0, 'M02', 31),
#   (1, 'M00', 86),
#   (2, 'M01', 46),
#   (3, 'M05', 74),
#   (4, 'M04', 32),
#   (5, 'M06', 88),
#   (6, 'M08', 19),
#   (7, 'M09', 48),
#   (8, 'M07', 36),
#   (9, 'M03', 79)]}

# %%
times_dict = get_times_dict(df_jobs_times_current)
times_dict
# Out:
# {'J25-0000': (1440, 3660),
#  'J25-0002': (1440, 3744),
#  'J25-0003': (1440, 3379),
#  'J25-0004': (1440, 4856),
#  'J25-0005': (1440, 3106),
#  'J25-0006': (1440, 3539),
#  'J25-0007': (1440, 2929),
#  'J25-0008': (1440, 3541),
#  'J25-0009': (1440, 3578),
#  'J25-0010': (1440, 3345),
#  'J25-0011': (1440, 3210),
#  'J25-0012': (1440, 4385),
#  'J25-0014': (1440, 3315),
#  'J25-0015': (1440, 2981),
#  'J25-0016': (2880, 4558),
#  'J25-0017': (2880, 4980),
#  'J25-0018': (2880, 4772),
#  'J25-0019': (2880, 4621),
#  'J25-0020': (2880, 4834),
#  'J25-0021': (2880, 5368),
#  'J25-0022': (2880, 4784),
#  'J25-0023': (2880, 4676),
#  'J25-0024': (2880, 4809),
#  'J25-0025': (2880, 4780),
#  'J25-0026': (2880, 4415),
#  'J25-0027': (2880, 5711),
#  'J25-0028': (2880, 5291),
#  'J25-0029': (2880, 4675),
#  'J25-0030': (2880, 6015),
#  'J25-0031': (2880, 4377),
#  'J25-0032': (2880, 3881),
#  'J25-0033': (2880, 6738),
#  'J25-0034': (2880, 6387),
#  'J25-0035': (2880, 4126),
#  'J25-0036': (2880, 5231),
#  'J25-0037': (2880, 5173)}

# %%
active_ops = get_active_ops(df_active)
active_ops
# Out:
# [('J25-0000', 4, 'M02', 2852, 93, 2945),
#  ('J25-0009', 3, 'M05', 2852, 65, 2917),
#  ('J25-0011', 8, 'M07', 2822, 77, 2899)]

# %%
previous_schedule = schedule

# %% [markdown]
# ### Scheduling (Rescheduling)

# %% [markdown]
# #### a) Simple Scheduling

# %%
schedule = solve_jssp_lateness_with_start_deviation(
    job_ops=job_ops_dict,
    times_dict=times_dict,
    previous_schedule=None,
    active_ops=active_ops,
    w_t= 10, w_e=2, w_first=1,
    main_pct=1,
    duration_buffer_factor = 2,
    schedule_start=day_start, msg=False,
    solver_time_limit=max_time, solver_relative_gap_limit=0.05
)

df_schedule = get_schedule_dframe(schedule)
gantt.get_plot(df_schedule, perspective="Machine")

df_schedule_with_info = enrich_schedule_dframe(df_schedule, df_jobs_times)
check.all_in_one(df_schedule_with_info)
# Out:
# Model Information
#   Number of variables       : 799
#   Number of constraints     : 1065
#   Deviation terms (IntVars) : 0
#
# Solver Information
#   Solver status             : OPTIMAL
#   Objective value           : 50.0
#   Best objective bound      : 50.0
#   Number of branches        : 136
#   Wall time                 : 2.57 seconds
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
#
# +++ Alle Constraints wurden erfüllt.
# True

# %% [markdown]
# ### b) with Deviation penalty

# %%
schedule = solve_jssp_lateness_with_start_deviation(
    job_ops=job_ops_dict,
    times_dict=times_dict,
    previous_schedule=previous_schedule,
    active_ops=active_ops,
    w_t= 10, w_e=2, w_first=1,
    main_pct=0.4,                  # 40% Lateness, 60% Deviation
    duration_buffer_factor = 2,
    schedule_start=day_start, msg=False,
    solver_time_limit=max_time, solver_relative_gap_limit=0.05
)

df_schedule = get_schedule_dframe(schedule)
gantt.get_plot(df_schedule, perspective="Machine")

df_schedule_with_info = enrich_schedule_dframe(df_schedule, df_jobs_times)
check.all_in_one(df_schedule_with_info)
# Out:
# Model Information
#   Number of variables       : 937
#   Number of constraints     : 1203
#   Deviation terms (IntVars) : 69
#
# Solver Information
#   Solver status             : OPTIMAL
#   Objective value           : 3253.0
#   Best objective bound      : 3137.0
#   Number of branches        : 374
#   Wall time                 : 20.96 seconds
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
#
# +++ Alle Constraints wurden erfüllt.
# True

# %% [markdown]
# #### Check the conditions of the combined data set from the simulation data with the new schedule

# %%
df_reschedule = df_schedule_with_info

columns = ["Job", "Operation", "Machine", "Start", "Processing Time", "End"]
df_combined = pd.concat([df_execution, df_active[columns], df_reschedule[columns]], ignore_index=True)
gantt.get_plot(df_combined, perspective="Machine")
check.is_machine_conflict_free(df_combined)
check.is_operation_sequence_correct(df_combined)
check.is_job_timing_correct(df_combined)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# True

# %% [markdown]
# ### Simulation

# %%
simulation.run(dframe_schedule_plan = df_sched
# [Day 2 22:43:00] Job J25-0016 finished on M08 (after 76 minutes)
# [Day 2 22:48:00] Job J25-0019 finished on M09 (after 81 minutes)
# [Day 2 22:48:00] Job J25-0004 started on M09
# [Day 2 22:52:00] Job J25-0024 finished on M07 (after 115 minutes)
# [Day 2 22:53:00] Job J25-0031 finished on M05 (after 44 minutes)
# [Day 2 22:53:00] Job J25-0019 started on M05
# [Day 2 22:53:00] Job J25-0031 started on M07
# [Day 2 23:01:00] Job J25-0022 finished on M01 (after 51 minutes)
# [Day 2 23:01:00] Job J25-0017 started on M01
# [Day 2 23:01:00] Job J25-0022 started on M00
# [Day 2 23:04:00] Job J25-0004 finished on M09 (after 16 minutes)
# [Day 2 23:04:00] Job J25-0018 started on M09
# [Day 2 23:13:00] Job J25-0022 finished on M00 (after 12 minutes)
# [Day 2 23:16:00] Job J25-0018 finished on M09 (after 12 minutes)
# [Day 2 23:16:00] Job J25-0020 started on M09
# [Day 2 23:16:00] Job J25-0018 started on M06
# [Day 2 23:25:00] Job J25-0025 finished on M02 (after 74 minutes)
# [Day 2 23:25:00] Job J25-0020 finished on M09 (after 09 minutes)
# [Day 2 23:25:00] Job J25-0022 started on M02
# [Day 2 23:25:00] Job J25-0025 started on M08
# [Day 2 23:39:00] Job J25-0019 finished on M05 (after 46 minutes)
# [Day 2 23:45:00] Job J25-0017 finished on M01 (after 44 minutes)
# [Day 2 23:53:00] Job J25-0029 finished on M04 (after 72 minutes)

# %%
df_execution2 = simulation.get_finished_operations_df()
df_execution2
# Out:
#           Job  Operation Machine   Start  Processing Time     End
# 0    J25-0000          4     M02  2852.0             93.0  2945.0
# 1    J25-0000          5     M09  2970.0              9.0  2979.0
# 2    J25-0000          6     M06  3197.0             48.0  3245.0
# 3    J25-0000          7     M07  3247.0            102.0  3349.0
# 4    J25-0000          8     M04  3373.0             28.0  3401.0
# 5    J25-0000          9     M08  3586.0             89.0  3675.0
# ..        ...        ...     ...     ...              ...     ...
# 150  J25-0035          4     M08  3385.0             61.0  3446.0
# 151  J25-0035          5     M09  3462.0             41.0  3503.0
# 152  J25-0035          6     M00  3576.0             37.0  3613.0
# 153  J25-0035          7     M06  3613.0             56.0  3669.0
# 154  J25-0035          8     M04  3706.0              6.0  3712.0
# 155  J25-0035          9     M07  4110.0             27.0  4137.0
#
# [156 rows x 6 columns]

# %%
gantt.get_plot(df_execution2, perspective="Machine")

# %%
df_active2 = simulation.get_active_operations_df()
df_active2
# Out:
#         Job  Operation Machine   Start  Processing Time     End  Expected End
# 0  J25-0018          6     M06  4276.0             46.0  4322.0        4316.0
# 1  J25-0022          2     M02  4285.0             60.0  4345.0        4346.0
# 2  J25-0023          2     M03  4240.0             82.0  4322.0        4316.0
# 3  J25-0025          4     M08  4285.0             89.0  4374.0        4375.0
# 4  J25-0031          8     M07  4253.0             73.0  4326.0        4325.0

# %% [markdown]
# #### Check the conditions of the combined data set from the two simulation data sets

# %%
df_combined = pd.concat([df_execution, df_execution2], ignore_index=True)
gantt.get_plot(df_combined, perspective="Machine")
check.is_machine_conflict_free(df_combined)
check.is_operation_sequence_correct(df_combined)
check.is_job_timing_correct(df_combined)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# True
